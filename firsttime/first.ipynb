# %% [markdown]
# # Read this [tutorial](https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d) first

# %% [markdown]
# # Mount your google drive space
#
# Mount your google drive to this path `/content/gdrive`
#
# The path will like `/content/gdrive/My Drive/allTheThingsInYourDriveSpace`

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Change your work path to the folder containing your code

# %%
import os
os.chdir("gdrive/My Drive/colab/firsttime")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-4327d875a99c> in <module>()
#       1 import os
# ----> 2 os.chdir("gdrive/My Drive/colab/firsttime")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gdrive/My Drive/colab/firsttime'

# %%
# !ls
# Out:
# a.py  first.ipynb

# %%
from a import hello

hello()

# %% [markdown]
# This is an example showing how to use this free service provided by google.

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
from mnist import MNIST
data = MNIST(data_dir="data/MNIST/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-cb8c74937e31> in <module>()
#       1
# ----> 2 from mnist import MNIST
#       3 data = MNIST(data_dir="data/MNIST/")
#
# ImportError: cannot import name 'MNIST'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #Markdown
# ## Hello
#
# ## First of ALL
#
# + We need a computer with a browsser.
# + We need know how to program.
