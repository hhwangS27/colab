# %% [markdown]
# # Set up environment like before

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir("/content/gdrive/My Drive/colab/secondtime")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # For example, we want to run the code in this [link](https://github.com/anishathalye/neural-style).
#
# + Go to the link.
# + clike the green button `Clone or download` as shown below.
# + clike Use HTTP. Make sure use the http way.
# + click the button circled by red circle as shown below.
#
# ![image alt >](https://github.com/hhwangS27/colab/blob/master/secondtime/1.png?raw=true)
#
# + use the code below to fetch the code to our google drive space

# %%
# !git clone https://github.com/anishathalye/neural-style.git
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 266 (delta 7), reused 15 (delta 6), pack-reused 248
# Receiving objects: 100% (266/266), 2.63 MiB | 13.53 MiB/s, done.
# Resolving deltas: 100% (138/138), done.

# %% [markdown]
# # Now, we will have a folder named `neural-style` in our current path.
#
# Let's then move ourselves to the new folder. You can use `!ls` to show the file list.

# %%
os.chdir("/content/gdrive/My Drive/colab/secondtime/neural-style")
# !ls
# Out:
# examples     neural_style.py  requirements.txt	vgg.py
# LICENSE.txt  README.md	      stylize.py

# %%
# Out:
# examples     neural_style.py  requirements.txt	vgg.py
# LICENSE.txt  README.md	      stylize.py

# %% [markdown]
# # Open this [link]() and scroll down you can see the content of `README.md`.
#
# It denotes requirement of Pre-trained VGG network and four python modules:
# + TensorFlow: the deep leanring frame
# + NumPy: module for commputing matrix on which TensorFlow bases
# + SciPy: more powerful mathmatical module
# + Pillow: an extension of image processing module PIL (Python Imaging Library)
